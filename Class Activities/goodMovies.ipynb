# %%
# Dependencies
import pandas as pd

# %%
# Load in File from resources
df = pd.read_csv('Resources/movie_scores.csv')
# 'movie_scores.csv'

# %%
# Read and display with pandas
df.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 0     3.70           4.3  ...       3.90            3.5                 4.5
# 1     4.25           4.0  ...       3.55            4.5                 4.0
# 2     4.00           4.5  ...       3.90            4.0                 4.5
# 3     0.90           4.2  ...       2.70            1.0                 4.0
# 4     0.70           1.4  ...       2.55            0.5                 1.5
#
#    Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 0                    3.5                         3.5              4.0
# 1                    3.5                         4.0              3.5
# 2                    3.0                         4.0              4.0
# 3                    1.0                         2.5              2.5
# 4                    1.5                         1.5              2.5
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Fandango_votes  \
# 0                        1330                271107           14846
# 1                         249                 65709           12640
# 2                         627                103660           12055
# 3                          31                  3136            1793
# 4                          88                 19560            1021
#
#    Fandango_Difference
# 0                  0.5
# 1                  0.5
# 2                  0.5
# 3                  0.5
# 4                  0.5
#
# [5 rows x 22 columns]

# %%
# List all the columns the table provides
df.columns
# Out:
# Index(['FILM', 'RottenTomatoes', 'RottenTomatoes_User', 'Metacritic',
#        'Metacritic_User', 'IMDB', 'Fandango_Stars', 'Fandango_Ratingvalue',
#        'RT_norm', 'RT_user_norm', 'Metacritic_norm', 'Metacritic_user_nom',
#        'IMDB_norm', 'RT_norm_round', 'RT_user_norm_round',
#        'Metacritic_norm_round', 'Metacritic_user_norm_round',
#        'IMDB_norm_round', 'Metacritic_user_vote_count', 'IMDB_user_vote_count',
#        'Fandango_votes', 'Fandango_Difference'],
#       dtype='object')

# %%
# only care about Imdb, so create a new table that takes the Film and all the columns relating to IMDB
imdbtbl = df[['FILM', 'IMDB', 'IMDB_norm', 'IMDB_norm_round', 'IMDB_user_vote_count']]
imdbtbl
imdbtbl = imdbtbl.set_index('FILM')
imdbtbl
# Out:
#                                            IMDB  IMDB_norm  IMDB_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)              7.8       3.90              4.0
# Cinderella (2015)                           7.1       3.55              3.5
# Ant-Man (2015)                              7.8       3.90              4.0
# Do You Believe? (2015)                      5.4       2.70              2.5
# Hot Tub Time Machine 2 (2015)               5.1       2.55              2.5
# ...                                         ...        ...              ...
# Mr. Holmes (2015)                           7.4       3.70              3.5
# '71 (2015)                                  7.2       3.60              3.5
# Two Days, One Night (2014)                  7.4       3.70              3.5
# Gett: The Trial of Viviane Amsalem (2015)   7.8       3.90              4.0
# Kumiko, The Treasure Hunter (2015)          6.7       3.35              3.5
#
#                                            IMDB_user_vote_count
# FILM
# Avengers: Age of Ultron (2015)                           271107
# Cinderella (2015)                                         65709
# Ant-Man (2015)                                           103660
# Do You Believe? (2015)                                     3136
# Hot Tub Time Machine 2 (2015)                             19560
# ...                                                         ...
# Mr. Holmes (2015)                                          7367
# '71 (2015)                                                24116
# Two Days, One Night (2014)                                24345
# Gett: The Trial of Viviane Amsalem (2015)                  1955
# Kumiko, The Treasure Hunter (2015)                         5289
#
# [146 rows x 4 columns]

# %%
# List only movies whose ratings are over 7 (out of 10) in IMDB
key = imdbtbl['IMDB']>7 #creates new table of only match_val
df7 = imdbtbl[key]
# Out:
#                                            IMDB  IMDB_norm  IMDB_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)              7.8       3.90              4.0
# Cinderella (2015)                           7.1       3.55              3.5
# Ant-Man (2015)                              7.8       3.90              4.0
# The Water Diviner (2015)                    7.2       3.60              3.5
# Shaun the Sheep Movie (2015)                7.4       3.70              3.5
# ...                                         ...        ...              ...
# Inside Out (2015)                           8.6       4.30              4.5
# Mr. Holmes (2015)                           7.4       3.70              3.5
# '71 (2015)                                  7.2       3.60              3.5
# Two Days, One Night (2014)                  7.4       3.70              3.5
# Gett: The Trial of Viviane Amsalem (2015)   7.8       3.90              4.0
#
#                                            IMDB_user_vote_count
# FILM
# Avengers: Age of Ultron (2015)                           271107
# Cinderella (2015)                                         65709
# Ant-Man (2015)                                           103660
# The Water Diviner (2015)                                  39373
# Shaun the Sheep Movie (2015)                              12227
# ...                                                         ...
# Inside Out (2015)                                         96252
# Mr. Holmes (2015)                                          7367
# '71 (2015)                                                24116
# Two Days, One Night (2014)                                24345
# Gett: The Trial of Viviane Amsalem (2015)                  1955
#
# [64 rows x 4 columns]

# %%
# Find lesser-known movies to watch, with fewer than 20K votes
vote_count = imdbtbl['IMDB_user_vote_count']<20000
df20k = imdbtbl[vote_count]
df20k
# Out:
#                                            IMDB  IMDB_norm  IMDB_norm_round  \
# FILM
# Do You Believe? (2015)                      5.4       2.70              2.5
# Hot Tub Time Machine 2 (2015)               5.1       2.55              2.5
# Irrational Man (2015)                       6.9       3.45              3.5
# Top Five (2014)                             6.5       3.25              3.5
# Shaun the Sheep Movie (2015)                7.4       3.70              3.5
# ...                                         ...        ...              ...
# Danny Collins (2015)                        7.1       3.55              3.5
# Serena (2015)                               5.4       2.70              2.5
# Mr. Holmes (2015)                           7.4       3.70              3.5
# Gett: The Trial of Viviane Amsalem (2015)   7.8       3.90              4.0
# Kumiko, The Treasure Hunter (2015)          6.7       3.35              3.5
#
#                                            IMDB_user_vote_count
# FILM
# Do You Believe? (2015)                                     3136
# Hot Tub Time Machine 2 (2015)                             19560
# Irrational Man (2015)                                      2680
# Top Five (2014)                                           16876
# Shaun the Sheep Movie (2015)                              12227
# ...                                                         ...
# Danny Collins (2015)                                      11206
# Serena (2015)                                             12165
# Mr. Holmes (2015)                                          7367
# Gett: The Trial of Viviane Amsalem (2015)                  1955
# Kumiko, The Treasure Hunter (2015)                         5289
#
# [79 rows x 4 columns]

# %%
# Finally, export this file to an Excel spreadsheet -- without the DataFrame index.
